# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# %%
tm_api_key = "hfaPAsQBjuEI58d2ekt6tlWi46Fzc1pY"

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Set up lists to hold reponse info
city = []
state_code = []
postal_code = []
country_code = []
local_date = []
latitude = []
longitude = []
max_price = []

count = 0

# %%
url = "https://app.ticketmaster.com/discovery/v2/events?apikey=hfaPAsQBjuEI58d2ekt6tlWi46Fzc1pY&keyword=Lizzo&locale=*&countryCode=US"

# %%
# Print the response object to the console
print(requests.get(url))
# Out:
# <Response [200]>

# %%
f = open("Concerts.json","w")

# %%
 # Retrieving data and converting it into JSON
print(requests.get(url).json())
# Out:
# {'_embedded': {'events': [{'name': 'Lizzo', 'type': 'event', 'id': 'Z7r9jZ1Ae_PQF', 'test': False, 'url': 'http://www.ticketsnow.com/InventoryBrowse/TicketList.aspx?PID=2665688', 'locale': 'en-us', 'images': [{'ratio': '4_3', 'url': 'https://s1.ticketm.net/dam/a/87c/bf775ca2-e6cd-463a-9ff6-60459f33d87c_1094781_CUSTOM.jpg', 'width': 305, 'height': 225, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/87c/bf775ca2-e6cd-463a-9ff6-60459f33d87c_1094781_RETINA_PORTRAIT_16_9.jpg', 'width': 640, 'height': 360, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/87c/bf775ca2-e6cd-463a-9ff6-60459f33d87c_1094781_ARTIST_PAGE_3_2.jpg', 'width': 305, 'height': 203, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/87c/bf775ca2-e6cd-463a-9ff6-60459f33d87c_1094781_TABLET_LANDSCAPE_LARGE_16_9.jpg', 'width': 2048, 'height': 1152, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/87c/bf775ca2-e6cd-463a-9ff6
# ...

# %%
# Pretty Print the output of the JSON
response = requests.get(url).json()
response
# Out:
# {'_embedded': {'events': [{'name': 'Lizzo',
#     'type': 'event',
#     'id': 'Z7r9jZ1Ae_PQF',
#     'test': False,
#     'url': 'http://www.ticketsnow.com/InventoryBrowse/TicketList.aspx?PID=2665688',
#     'locale': 'en-us',
#     'images': [{'ratio': '4_3',
#       'url': 'https://s1.ticketm.net/dam/a/87c/bf775ca2-e6cd-463a-9ff6-60459f33d87c_1094781_CUSTOM.jpg',
#       'width': 305,
#       'height': 225,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/87c/bf775ca2-e6cd-463a-9ff6-60459f33d87c_1094781_RETINA_PORTRAIT_16_9.jpg',
#       'width': 640,
#       'height': 360,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/87c/bf775ca2-e6cd-463a-9ff6-60459f33d87c_1094781_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
#       'fallback': False},
#      {'ratio': '16_9',
# ...

# %%
#print(json.dumps(response["_embedded"]["events"][0], indent=4, sort_keys=True))
j = (json.dumps(response, indent=4, sort_keys=True))

# %%
f.write(j)
# Out:
# 631331

# %%
f.close()
